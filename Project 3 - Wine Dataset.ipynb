# %%
#Steps to perform machine learning for Wine Dataset
#Loading the library
#Loading the datasets, 
#Sumarizing the datasets 
#Visualizing the datasets
#Evaluting the datasets 
#Making some Prediction

# %% [markdown]
# ## EDA- Exploratory Data Analysis

# %%
#import library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#import the wine.csv file
df=pd.read_csv('wine.csv')

# %%
#get some information from the data

# %%
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  diluted wines  Proline
# 0             5.64  1.04           3.92         1065
# 1             4.38  1.05           3.40         1050
# ...

# %%
df.tail()
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 173           1.68        0.61                  0.52             1.06
# 174           1.80        0.75                  0.43             1.41
# 175           1.59        0.69                  0.43             1.35
# 176           1.65        0.68                  0.53             1.46
# 177           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  diluted wines  Proline
# 173              7.7  0.64           1.74          740
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.dtypes
# Out:
# Class                     int64
# Alcohol                 float64
# Malic acid              float64
# Ash                     float64
# Alcalinity of ash       float64
# Magnesium                 int64
# Total phenols           float64
# Flavanoids              float64
# Nonflavanoid phenols    float64
# Proanthocyanins         float64
# Color intensity         float64
# Hue                     float64
# diluted wines           float64
# Proline                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %%
#all columns numerical

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity of ash     178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  diluted wines         178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %% [markdown]
# ### Summary Statistics

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %% [markdown]
# key observation: #1 The median(50th percentile) is more than mean in all columns,
#
# #2 There is a large difference in 75% percentile and max in Magnesium and Proline
# #3 The 1 and 2 obervation suggest that there are outliers paresent in these three columns

# %% [markdown]
# ### Exploring data variable

# %%
df.Class.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df.Class.value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#lets check whether the null values are present in the dataset or not using heatmap
sns.heatmap(df.isnull(),annot=True)
plt.show()

# %%
# lests check the null values without using visualization
df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# diluted wines           0
# Proline                 0
# dtype: int64

# %% [markdown]
# ### To check correlation

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)

# %%
#Light shades are highly correlated
#class highly negatively correlated with Proline,diluted wines,Hue,Total Phenols,Flavanoids
#class is positivly highly correlated with Malic acid,Alcalinity of as

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,cmap='tab10')
plt.show()

# %% [markdown]
# ### Univariate Analysis

# %%
plt.hist(x='Magnesium',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Alcohol',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Malic acid',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Ash',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Alcalinity of ash',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Magnesium',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Total phenols',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Flavanoids',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Nonflavanoid phenols',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Proanthocyanins',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Color intensity',bins=10,data=df)
plt.show()

# %%
plt.hist(x='diluted wines',bins=10,data=df)
plt.show()

# %%
plt.hist(x='Hue',bins=10,data=df)
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
# start with class
sns.barplot(x=df['Class'],y=df['Alcohol'],data=df)
plt.show()

# %%
sns.barplot(x=df['Class'],y=df['Malic acid'],data=df)
plt.show()

# %%
#above grafh show %of Malic acid in maximun in Class 3

# %%
sns.barplot(x=df['Class'],y=df['Ash'],data=df)
plt.show()

# %%
sns.barplot(x=df['Class'],y=df['Alcalinity of ash'],data=df)
plt.show()

# %%
# above grafh show the % of Alcalinity of ash more in Class 3

# %%
sns.barplot(x=df['Class'],y=df['Magnesium'],data=df)
plt.show()
# magneisium % is maximum in Class 1

# %%
sns.barplot(x=df['Class'],y=df['Total phenols'],data=df)
plt.show()

# %%
#above grafh show the % of Total phenols is maximum in Class 1

# %%
sns.barplot(x=df['Class'],y=df['Flavanoids'],data=df)
plt.show()

# %%
#Flavanoids % in Class 1 is much higher than Class 3

# %%
sns.barplot(x=df['Class'],y=df['Nonflavanoid phenols'],data=df)
plt.show()

# %%
# % of Nonflavanoid phenols is maximum in Class 3

# %%
sns.barplot(x=df['Class'],y=df['Proanthocyanins'],data=df)
plt.show()

# %%
sns.barplot(x=df['Class'],y=df['Color intensity'],data=df)
plt.show()

# %%
sns.barplot(x=df['Class'],y=df['Hue'],data=df)
plt.show()

# %%
sns.barplot(x=df['Class'],y=df['diluted wines'],data=df)
plt.show()

# %%
sns.lineplot(x=df['Alcohol'],y=df['diluted wines'],data=df)
plt.show()

# %%
sns.lineplot(x=df['Alcohol'],y=df['Alcalinity of ash'],data=df)
plt.show()

# %%
sns.lineplot(x=df['Alcohol'],y=df['Total phenols'],data=df)
plt.show()

# %%
sns.lineplot(x=df['Alcohol'],y=df['Color intensity'],data=df)
plt.show()

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B2CA93A808>,
# ...
#       dtype=object)

# %%
sns.pairplot(df)

# %% [markdown]
# ## Plotting Outliers

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %%
df.shape
# Out:
# (178, 14)

# %%
collist=df.columns.values
ncol=14
nrows=12

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(0,len(collist)):
           plt.subplot(nrows,ncol,i+1)
           sns.boxplot(df[collist[i]],color='green',orient='v')
           plt.tight_layout()

# %% [markdown]
# ## To check the distribution of Skewness

# %%
df.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              1.039651
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               1.098191
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.868585
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.767822
# dtype: float64

# %%
plt.figure(figsize=(16,16))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %%
# Removing skewness using for loop

# %%
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col]=np.log(df[col])

# %%
df.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              0.274613
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               0.601445
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity        -0.080464
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.086823
# dtype: float64

# %% [markdown]
# ## Removing outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.21394365, 1.51861254, 0.46448718, ..., 0.36217728, 1.84791957,
#         1.06399053],
#        [1.21394365, 0.24628963, 0.3751346 , ..., 0.40605066, 1.1134493 ,
#         1.02972309],
#        [1.21394365, 0.19687903, 0.25302455, ..., 0.31830389, 0.78858745,
#         1.32192211],
#        ...,
#        [1.37386437, 0.33275817, 1.57881801, ..., 1.61212515, 1.48544548,
#         0.47622694],
#        [1.37386437, 0.20923168, 0.46013964, ..., 1.56825176, 1.40069891,
#         0.49064975],
#        [1.37386437, 1.39508604, 1.48312691, ..., 1.52437837, 1.42894777,
#         0.48887858]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 25,  59,  69,  73,  95, 110, 115, 121, 121], dtype=int64), array([ 3,  3,  5,  4,  5,  9, 11,  3,  7], dtype=int64))

# %%
z[25][3]
# Out:
# 3.1197718608780005

# %%
z[121][7]
# Out:
# 3.0628317372525964

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (170, 14)

# %%
df.shape
# Out:
# (178, 14)

# %%
#8 row dedected as outliers

# %%
df=df_new

# %%
df.shape
# Out:
# (170, 14)

# %%
df.skew()
# Out:
# Class                   0.104977
# Alcohol                -0.030651
# Malic acid              0.257826
# Ash                    -0.243064
# Alcalinity of ash       0.094425
# Magnesium               0.268171
# Total phenols           0.111388
# Flavanoids             -0.076427
# Nonflavanoid phenols    0.474603
# Proanthocyanins         0.354703
# Color intensity        -0.117212
# Hue                    -0.121305
# diluted wines          -0.279718
# Proline                 0.079942
# dtype: float64

# %% [markdown]
# ## Model Training By Classifiaction

# %%
# Now Lets seprate imnput and output variable to be used for the clasification problem
x=df.drop('Class',axis=1)
x
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23    0.536493  2.43               15.6   4.844187           2.80
# 1      13.20    0.576613  2.14               11.2   4.605170           2.65
# 2      13.16    0.858662  2.67               18.6   4.615121           2.80
# 3      14.37    0.667829  2.50               16.8   4.727388           3.85
# 4      13.24    0.951658  2.87               21.0   4.770685           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71    1.731656  2.45               20.5   4.553877           1.68
# 174    13.40    1.363537  2.48               23.0   4.624973           1.80
# 175    13.27    1.453953  2.26               20.0   4.787492           1.59
# 176    13.17    0.951658  2.37               20.0   4.787492           1.65
# 177    14.13    1.410987  2.74               24.5   4.564348           2.05
#
# ...

# %%
y=df['Class']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Class, Length: 170, dtype: int64

# %%
print(x.shape,y.shape)
# Out:
# (170, 13) (170,)

# %%
# Scaling down using StandardScaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.50053916e+00, -4.87303911e-01,  2.47809541e-01, ...,
#          4.17466724e-01,  1.86240588e+00,  1.04719238e+00],
#        [ 2.00660830e-01, -3.97971249e-01, -9.45257879e-01, ...,
#          4.62687409e-01,  1.13104486e+00,  1.01325153e+00],
#        [ 1.50180118e-01,  2.30047825e-01,  1.23517568e+00, ...,
#          3.72246039e-01,  8.07558250e-01,  1.30266577e+00],
#        ...,
#        [ 2.89002076e-01,  1.55554565e+00, -4.51574808e-01, ...,
#         -1.61746410e+00, -1.45684799e+00,  4.65030420e-01],
#        [ 1.62800296e-01,  4.37116729e-01,  9.68006020e-04, ...,
#         -1.57224342e+00, -1.37246018e+00,  4.79315778e-01],
#        [ 1.37433738e+00,  1.45987589e+00,  1.52315747e+00, ...,
#         -1.52702273e+00, -1.40058945e+00, -4.90877240e-01]])

# %%
# import library
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42,stratify=y)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 1.0
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34

# %%
svc=SVC(kernel='rbf')    #kernel='rbf'_____>default
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 1.0
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34

# %%
#DecsionTreeClassifier(criterion='gini')  _____default
#DecisionTreeClassifier(criterion='entropy')
#Gini and entrophy

dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.9117647058823529
# [[11  1  0]
#  [ 1 11  1]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            1       0.92      0.92      0.92        12
#            2       0.92      0.85      0.88        13
#            3       0.90      1.00      0.95         9
#
#     accuracy                           0.91        34
#    macro avg       0.91      0.92      0.91        34
# weighted avg       0.91      0.91      0.91        34

# %%
# k=10
knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
knc.score(x_train,y_train)
predknc=knc.predict(x_test)
print(accuracy_score(y_test,predknc))
print(confusion_matrix(y_test,predknc))
print(classification_report(y_test,predknc))
# Out:
# 0.9117647058823529
# [[12  0  0]
#  [ 2 10  1]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            1       0.86      1.00      0.92        12
#            2       1.00      0.77      0.87        13
#            3       0.90      1.00      0.95         9
#
#     accuracy                           0.91        34
#    macro avg       0.92      0.92      0.91        34
# weighted avg       0.92      0.91      0.91        34

# %%
def svmkernel(ker):
    svc=SVC(kernel=ker)
    svc.fit(x_train,y_train)
    svc.score(x_train,y_train)
    predsvc=svc.predict(x_test)
    print(accuracy_score(y_test,predsvc))
    print(confusion_matrix(y_test,predsvc))
    print(classification_report(y_test,predsvc))

# %%
svmkernel('rbf')
# Out:
# 1.0
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34

# %%
svmkernel('poly')
# Out:
# 1.0
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34

# %%
svmkernel('linear')
# Out:
# 1.0
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34

# %%
#Using Grid Search to check the best parameters for SVM

from sklearn.model_selection import GridSearchCV
svc=SVC()
parameters={'kernel':('linear','poly','rbf'),'C':[1,10]}
clf=GridSearchCV(svc,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
#Using SVC() from SVM

svc=SVC(kernel='rbf',C=1)
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 1.0
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34

# %%
model=[DecisionTreeClassifier(),SVC(),KNeighborsClassifier(),LogisticRegression()]

# %%
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Accuracy Score of',m,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy Score of DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best') is:
# 0.9411764705882353
# [[11  1  0]
#  [ 0 12  1]
#  [ 0  0  9]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.92      0.96        12
#            2       0.92      0.92      0.92        13
#            3       0.90      1.00      0.95         9
#
#     accuracy                           0.94        34
#    macro avg       0.94      0.95      0.94        34
# weighted avg       0.94      0.94      0.94        34
#
#
#
# ...

# %%
#Cross Validate Logistic Regression

from sklearn.model_selection import cross_val_score    

lr=LogisticRegression()
score=cross_val_score(lr,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.97058824 0.97058824 1.         1.         1.        ]
# 0.9882352941176471
# 0.014408763192842226

# %%
#Cross validate SVC

svc=SVC()
score=cross_val_score(svc,x,y,cv=5,scoring='f1_micro')
print(score)
print(score.mean())
print(score.std())
# Out:
# [1.         0.97058824 1.         1.         1.        ]
# 0.9941176470588236
# 0.011764705882352944

# %%
#SVC is working well
#Saving the model
from sklearn.externals import joblib
joblib.dump(svc,'wine.pkl')
# Out:
# ['wine.pkl']
